# %% [markdown]
# # TSFM_forecasting

# %% [markdown]
# ## 一、需要下载对应的模型
#
# 模型下载地址分别是：
#
# ### 1. Chronos-2
#
# [Chronos-2 模型下载地址](https://huggingface.co/amazon/chronos-2)
#
# ### 2. Toto-2
#
# [Toto-2.0-22m 模型下载地址](https://huggingface.co/Datadog/Toto-2.0-22m)
#
# > **注意：** Toto-2.0 提供不同参数规模的版本，可以根据实际的硬件配置和使用需求自行选择合适的模型。
#
# ### 3. TiRex-2
#
# [TiRex-2 模型下载地址](https://huggingface.co/NX-AI/TiRex-2)
#
# ### 4. 模型存放位置
#
# 将下载好的模型统一放置到项目的 `models` 目录下，例如：
#
# ```text
# 项目目录/
# ├── models/
# │   ├── chronos-2/
# │   ├── Toto-2.0-22m/
# │   └── TiRex-2/
# ├── ...

# %% [markdown]
# ## 二、配置依赖

# %% [markdown]
# pip install -r requirements.txt

# %% [markdown]
# ## 三、示例（chronos-2，使用协变量）

# %%
import pandas as pd
from load_model_function.pred_with_chronos import ChronosFunctionWithCovariate
from tools.result_save import save_forecast_to_csv

#原始数据地址
data=pd.read_excel("test_data\股票指数日度行情数据.xlsx")
#协变量原始数据地址
co_data=pd.read_excel("test_data\宏观经济指标日度数据.xlsx")
#原始数据中选择进行预测的变量
variate_list=["开盘价","收盘价"]
#从协变量数据中选择辅助进行预测的协变量
co_variate_list=["GDP同比(%)","CPI同比(%)","M2同比(%)","失业率(%)"]
#历史步长（即使用历史的多少数据对未来进行预测）
context_len=64
#预测步长（即预测未来多少长度的数据）
pred_len=12
#选择模型的地址
model_path=r"models\Chronos-2"
#种子
seed=2026
#测试集长度（默认使用整个传入的数据集作为测试集，不过是排除掉context_len的剩下长度）
n=len(data)

data=data.iloc[-n:,:]
co_data=co_data.iloc[-n:,:]
data=data.loc[:,variate_list]
co_data=co_data.loc[:,co_variate_list]

model=ChronosFunctionWithCovariate(data=data,
                                    co_data=co_data,
                                    context_len=context_len,
                                    pred_len=pred_len,
                                    stride=pred_len,
                                    model_path=model_path,
                                    seed=seed)
#验证
true_data1,pred_median_data1,pred_up_data1,pred_down_data1=model.chronoswithcovariate_valid()
print(true_data1.shape,pred_median_data1.shape,pred_up_data1.shape,pred_down_data1.shape)

#预测
pred_median_data,pred_up_data,pred_down_data=model.chronoswithcovariate_predict()
print(pred_median_data.shape,pred_up_data.shape,pred_down_data.shape)
# Out:
# Loading weights: 100%|██████████| 170/170 [00:00<00:00, 9588.53it/s]
# 3it [00:00, 12.78it/s]
# (2, 36) (2, 36) (2, 36) (2, 36)
# Loading weights: 100%|██████████| 170/170 [00:00<00:00, 7082.72it/s]
# 1it [00:00,  9.05it/s]
# (2, 12) (2, 12) (2, 12)

# %% [markdown]
# ## 四、示例（chronos-2，不使用协变量）

# %%
import pandas as pd
from load_model_function.pred_with_chronos import ChronosFunction
from tools.result_save import save_forecast_to_csv

#原始数据地址
data=pd.read_excel("test_data\股票指数日度行情数据.xlsx")
#原始数据中选择进行预测的变量
variate_list=["开盘价","收盘价"]
#历史步长（即使用历史的多少数据对未来进行预测）
context_len=64
#预测步长（即预测未来多少长度的数据）
pred_len=12
#选择模型的地址
model_path=r"models\Chronos-2"
#种子
seed=2026
#测试集长度（默认使用整个传入的数据集作为测试集，不过是排除掉context_len的剩下长度）
n=len(data)

data=data.iloc[-n:,:]
co_data=co_data.iloc[-n:,:]
data=data.loc[:,variate_list]
co_data=co_data.loc[:,co_variate_list]

model=ChronosFunction(data=data,
                    context_len=context_len,
                    pred_len=pred_len,
                    stride=pred_len,
                    model_path=model_path,
                    seed=seed)

#验证
true_data1,pred_median_data1,pred_up_data1,pred_down_data1=model.chronos_valid()
print(true_data1.shape,pred_median_data1.shape,pred_up_data1.shape,pred_down_data1.shape)

#预测
pred_median_data,pred_up_data,pred_down_data=model.chronos_predict()
print(pred_median_data.shape,pred_up_data.shape,pred_down_data.shape)
# Out:
# ...
# 100%|██████████| 3/3 [00:00<00:00, 15.81it/s]
# (2, 36) (2, 36) (2, 36) (2, 36)
# ...
# 100%|██████████| 1/1 [00:00<00:00, 10.05it/s]
# (2, 12) (2, 12) (2, 12)
